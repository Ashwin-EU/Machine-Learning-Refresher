# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/refs/heads/master/chapter-06-trees/CreditScoring.csv')
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.describe()
# Out:
#             Status    Seniority         Home         Time          Age  \
# count  4455.000000  4455.000000  4455.000000  4455.000000  4455.000000
# mean      1.281257     7.987205     2.657015    46.441751    37.077666
# std       0.450162     8.173444     1.610467    14.655225    10.984856
# min       0.000000     0.000000     0.000000     6.000000    18.000000
# 25%       1.000000     2.000000     2.000000    36.000000    28.000000
# 50%       1.000000     5.000000     2.000000    48.000000    36.000000
# 75%       2.000000    12.000000     4.000000    60.000000    45.000000
# max       2.000000    48.000000     6.000000    72.000000    68.000000
#
#            Marital      Records          Job     Expenses        Income  \
# count  4455.000000  4455.000000  4455.000000  4455.000000  4.455000e+03
# mean      1.879012     1.173513     1.675870    55.568799  7.633170e+05
# std       0.643748     0.378733     0.954035    19.515878  8.703625e+06
# ...

# %% [markdown]
# # Prepare Data

# %%
df.columns =df.columns.str.lower().str.replace(' ', '_')
df.head()
df.dtypes
# Out:
# status       int64
# seniority    int64
# home         int64
# time         int64
# age          int64
# marital      int64
# records      int64
# job          int64
# expenses     int64
# income       int64
# assets       int64
# debt         int64
# amount       int64
# price        int64
# dtype: object

# %%
status_values = {
    1: 'ok',
    2: 'default',
    0: 'unk'
}
df.status = df.status.map(status_values)

home_values = {
    1: 'rent',
    2: 'owner',
    3: 'private',
    4: 'ignore',
    5: 'parents',
    6: 'other',
    0: 'unk'
}
df.home = df.home.map(home_values)

marital_values = {
    1: 'single',
    2: 'married',
    3: 'widow',
    4: 'separated',
    5: 'divorced',
    0: 'unk'
}
df.marital = df.marital.map(marital_values)

record_values = {
    1: 'no',
    2: 'yes',
    0: 'unk'
}
df.records = df.records.map(record_values)

job_values = {
    1: 'fixed',
    2: 'partime',
    3: 'freelance',
    4: 'others',
    0: 'unk'
}
df.job = df.job.map(job_values)
df.head()
# Out:
#     status  seniority   home  time  age  marital records        job  expenses  \
# 0       ok          9   rent    60   30  married      no  freelance        73
# 1       ok         17   rent    60   58    widow      no      fixed        48
# 2  default         10  owner    36   46  married     yes  freelance        90
# 3       ok          0   rent    60   24   single      no      fixed        63
# 4       ok          0   rent    36   26   single      no      fixed        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses      income      assets  \
# count     4455.0  4455.0  4455.0    4455.0      4455.0      4455.0
# mean         8.0    46.0    37.0      56.0    763317.0   1060341.0
# std          8.0    15.0    11.0      20.0   8703625.0  10217569.0
# min          0.0     6.0    18.0      35.0         0.0         0.0
# 25%          2.0    36.0    28.0      35.0        80.0         0.0
# 50%          5.0    48.0    36.0      51.0       120.0      3500.0
# 75%         12.0    60.0    45.0      72.0       166.0      6000.0
# max         48.0    72.0    68.0     180.0  99999999.0  99999999.0
#
#              debt  amount    price
# count      4455.0  4455.0   4455.0
# mean     404382.0  1039.0   1463.0
# std     6344253.0   475.0    628.0
# min           0.0   100.0    105.0
# 25%           0.0   700.0   1118.0
# 50%           0.0  1000.0   1400.0
# 75%           0.0  1300.0   1692.0
# max    99999999.0  5000.0  11140.0

# %%
for c in ['income', 'assets', 'debt']:
    df[c] = df[c].replace(to_replace=99999999, value=np.nan)
df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4421.0    4408.0   4437.0  4455.0
# mean         8.0    46.0    37.0      56.0   131.0    5403.0    343.0  1039.0
# std          8.0    15.0    11.0      20.0    86.0   11573.0   1246.0   475.0
# min          0.0     6.0    18.0      35.0     0.0       0.0      0.0   100.0
# 25%          2.0    36.0    28.0      35.0    80.0       0.0      0.0   700.0
# 50%          5.0    48.0    36.0      51.0   120.0    3000.0      0.0  1000.0
# 75%         12.0    60.0    45.0      72.0   165.0    6000.0      0.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %%
df.status.value_counts(normalize=True)
# Out:
# status
# ok         0.718294
# default    0.281481
# unk        0.000224
# Name: proportion, dtype: float64

# %%
df = df[df.status != 'unk'].reset_index(drop=True)

# %% [markdown]
# # Train validation test split

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = (df_train.status == 'default').astype(int)
y_val = (df_val.status == 'default').astype(int)
y_test = (df_test.status == 'default').astype(int)

# %%
del df_train['status']
del df_val['status']
del df_test['status']

# %% [markdown]
# # Train Decision Tree

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeClassifier

# %%
df_train_dict = df_train.to_dict(orient='records')
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(df_train_dict)
dv.get_feature_names_out()
# Out:
# array(['age', 'amount', 'assets', 'debt', 'expenses', 'home=ignore',
#        'home=other', 'home=owner', 'home=parents', 'home=private',
#        'home=rent', 'home=unk', 'income', 'job=fixed', 'job=freelance',
#        'job=others', 'job=partime', 'job=unk', 'marital=divorced',
#        'marital=married', 'marital=separated', 'marital=single',
#        'marital=unk', 'marital=widow', 'price', 'records=no',
#        'records=yes', 'seniority', 'time'], dtype=object)

# %%
dt = DecisionTreeClassifier(max_depth=5, random_state=1)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)
y_pred = dt.predict_proba(X_val)[:, 1]

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_val, y_pred)
# Out:
# 0.7639156740404612

# %%
roc_auc_score(y_train, dt.predict_proba(X_train)[:, 1])
# Out:
# 0.8453460711959684

# %% [markdown]
# # Visualise Tree

# %%
from sklearn.tree import export_text
print(export_text(dt, feature_names=dv.get_feature_names_out().tolist()))
# Out:
# |--- income <= 89.50
# |   |--- seniority <= 2.50
# |   |   |--- records=no <= 0.50
# |   |   |   |--- age <= 53.50
# |   |   |   |   |--- time <= 21.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- time >  21.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- age >  53.50
# |   |   |   |   |--- class: 0
# |   |   |--- records=no >  0.50
# |   |   |   |--- assets <= 4050.00
# |   |   |   |   |--- amount <= 1120.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- amount >  1120.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- assets >  4050.00
# |   |   |   |   |--- price <= 1133.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- price >  1133.50
# |   |   |   |   |   |--- class: 0
# |   |--- seniority >  2.50
# |   |   |--- records=yes <= 0.50
# |   |   |   |--- assets <= 3550.00
# |   |   |   |   |--- job=fixed <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- job=fixed >  0.50
# |   |   |   |   |   |--- class: 0
# ...

# %% [markdown]
# # Decision trees Parameter Tuning

# %%
scores = []
for d in [3, 4, 5]:
    for s in [1, 2, 5, 10, 15, 20, 25, 30, 50, 100, 200, 300, 500]:
        dt = DecisionTreeClassifier(max_depth=d, min_samples_leaf=s, random_state=1)
        dt.fit(X_train, y_train)  
        y_pred = dt.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        scores.append((d, s, auc))
df_scores = pd.DataFrame(scores, columns=['max_depth', 'min_samples_leaf', 'auc'])
df_scores.sort_values(by='auc', ascending=False).head(10)
# Out:
#     max_depth  min_samples_leaf       auc
# 33          5                30  0.783229
# 34          5                50  0.780374
# 32          5                25  0.777655
# 22          4               100  0.777031
# 31          5                20  0.776921
# 16          4                10  0.776325
# 30          5                15  0.775972
# 17          4                15  0.775966
# 15          4                 5  0.775780
# 18          4                20  0.775742

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns='max_depth', values='auc')
sns.heatmap(df_scores_pivot, annot=True, fmt='.3f', linecolor='green', linewidths=0.5)
# Out:
# <Axes: xlabel='max_depth', ylabel='min_samples_leaf'>

# %% [markdown]
# # Train Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, random_state=1)
rf.fit(X_train, y_train)
y_pred = rf.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.8118453393836265

# %% [markdown]
# # Tune Random Forest Hyperparameters

# %%
n = 50
d = 5
s = 15
scores = []
for m in ['sqrt', 'log2']:
    rf = RandomForestClassifier(n_estimators=n, max_depth=d, max_features=m, min_samples_leaf=s, random_state=1)
    rf.fit(X_train, y_train)
    y_pred = rf.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    scores.append((n, d, s, m, auc))
scores_df = pd.DataFrame(scores, columns=['n_estimators', 'max_depth', 'min_samples_leaf', 'max_features', 'auc'])
scores_df.sort_values(by='auc', ascending=False).head(10)
# Out:
#    n_estimators  max_depth  min_samples_leaf max_features       auc
# 0            50          5                15         sqrt  0.814363
# 1            50          5                15         log2  0.812680

# %% [markdown]
# # Train XGBoost

# %%
# !pip install xgboost
import xgboost as xgb
features = dv.get_feature_names_out().tolist()
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 80.1 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 MB 57.9 MB/s  0:00:03m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [xgboost]m1/2 [xgboost]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# %%capture output
xgb_params = {
    'eta': 0.1,
    'max_depth': 5,
    'min_Child_weight': 1,
    'objective': 'binary:logistic',
    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
    'eval_metric': 'auc'
}  
watchlist = [(dtrain, 'train'), (dval, 'val')]
model = xgb.train(xgb_params, 
                  dtrain,
                  num_boost_round=10, 
                  evals=watchlist, 
                  early_stopping_rounds=50)

# %%
y_pred = model.predict(dval)
roc_auc_score(y_val, y_pred)
# Out:
# 0.8096174450116594

# %%
def parse_xgb_output(output):
    results = []
    for line in output.splitlines():
        if line.startswith('[0]'):
            continue
        epoch, rest = line.split('\t', 1)
        epoch = int(epoch[1:])
        train, val = rest.split('\t')
        train = float(train.split(':')[1])
        val = float(val.split(':')[1])
        results.append((epoch, train, val))
    return results

# %%
results = pd.DataFrame(parse_xgb_output(output.stdout), columns=['epoch', 'train_auc', 'val_auc'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 results = pd.DataFrame(parse_xgb_output(output.getvalue()), columns=['epoch', 'train_auc', 'val_auc'])
#
# AttributeError: 'CapturedIO' object has no attribute 'getvalue'
